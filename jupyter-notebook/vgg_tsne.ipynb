# %%
import numpy as np

# %%
import torch
torch.__version__
# Out:
# '1.8.1+cu102'

# %% [markdown]
# # 1. load model structure

# %% [markdown]
# ## 1.A load default model weight

# %%
import torch
from PIL import Image
from torchvision import transforms
import torchvision.models as models
model = models.vgg16(pretrained=True)
model.eval()
model.to('cuda')
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=4096, out_features=1000, bias=True)
#   )
# )

# %% [markdown]
# ## 1.B load weight from model

# %%
checkpoint  = torch.load('faster_rcnn_MI3_AVG_10.pth')

# %%
for l in list(model.features.modules())[0]:
    print (l)
# Out:
# Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# ReLU(inplace=True)
# Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# ReLU(inplace=True)
# MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
# Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# ReLU(inplace=True)
# Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# ReLU(inplace=True)
# MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
# Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# ReLU(inplace=True)
# Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# ReLU(inplace=True)
# Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# ReLU(inplace=True)
# MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
# Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# ReLU(inplace=True)
# Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# ReLU(inplace=True)
# Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# ReLU(inplace=True)
# MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
# Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# ReLU(inplace=True)
# Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# ReLU(inplace=True)
# Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# ReLU(inplace=True)
# MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)

# %%
for key, value in checkpoint['model'].items():
    
    if key.startswith('RCNN_base'):
        print(key)    
        #print(value.shape)
# Out:
# RCNN_base.0.weight
# RCNN_base.0.bias
# RCNN_base.2.weight
# RCNN_base.2.bias
# RCNN_base.5.weight
# RCNN_base.5.bias
# RCNN_base.7.weight
# RCNN_base.7.bias
# RCNN_base.10.weight
# RCNN_base.10.bias
# RCNN_base.12.weight
# RCNN_base.12.bias
# RCNN_base.14.weight
# RCNN_base.14.bias
# RCNN_base.17.weight
# RCNN_base.17.bias
# RCNN_base.19.weight
# RCNN_base.19.bias
# RCNN_base.21.weight
# RCNN_base.21.bias
# RCNN_base.24.weight
# RCNN_base.24.bias
# RCNN_base.26.weight
# RCNN_base.26.bias
# RCNN_base.28.weight
# RCNN_base.28.bias

# %%
layer_list = [0,2,5,7,10,12,14,17,19,21,24,26,28]
for layer in layer_list:
    weight_name = 'RCNN_base.'+str(layer)+'.weight'
    bias_name = 'RCNN_base.'+str(layer)+'.bias'
    model.features[layer].weight =torch.nn.Parameter( checkpoint['model'][weight_name]).to('cuda') 
    model.features[layer].bias =torch.nn.Parameter( checkpoint['model'][bias_name]).to('cuda')

# %%
model
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=4096, out_features=1000, bias=True)
#   )
# )

# %% [markdown]
# ## 2. Load data

# %% [markdown]
# ## 2A KAIST

# %%
import os
import numpy as np
import matplotlib.pyplot as plt      # plot library.
from IPython.display import display 
# %matplotlib inline

# TARGET_LAYER = 'fc'
TARGET_LAYER = 'avgpool'

# TARGET_LAYER = 'classifier'

preprocess = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

if torch.cuda.is_available():
    model.to('cuda')

# %%
def scene_tag(file_name):
    set_tag = file_name.split('_')[0][-2:]
    if set_tag == "06" or set_tag == "09":
        return 'campus'
    if set_tag == "07" or set_tag == "10":
        return 'road'
    if set_tag == "08" or set_tag == "11":
        return 'downtown'

# Dealing with the filename first.
BASE_DIR = '../kaist_test/kaist_test_visible'
file_names = [f for f in os.listdir(BASE_DIR) if '.png' in f]
scene_tags = [scene_tag(f) for f in file_names]

plt.hist(scene_tags);

# %%
# %%time 
imgs = [Image.open(os.path.join(BASE_DIR, fn)) for fn in file_names]
imgs = [preprocess(img).unsqueeze(0) for img in imgs]
# Out:
# CPU times: user 2min 32s, sys: 5.14 s, total: 2min 37s
# Wall time: 1min

# %% [markdown]
# ## 2B MI3

# %% [markdown]
# ###  load data info

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in /home/superorange5/.local/lib/python3.8/site-packages (1.4.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.8/site-packages (from pandas) (2021.1)
# Requirement already satisfied: numpy>=1.18.5 in /home/superorange5/.local/lib/python3.8/site-packages (from pandas) (1.22.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/superorange5/.local/lib/python3.8/site-packages (from pandas) (2.8.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.8/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# WARNING: You are using pip version 21.2.4; however, version 22.0.3 is available.
# You should consider upgrading via the '/opt/conda/bin/python3 -m pip install --upgrade pip' command.

# %%
import pandas as pd
header = ['scene','scene_num','channel','frame']
df = pd.read_csv('MI3_3325.txt', sep='_',names=header)
df
# Out:
#           scene  scene_num channel  frame
# 0      Pathway2          3     ch4    170
# 1          Room          1     ch2    113
# 2      Pathway2          2     ch2    156
# 3           Bus          2     ch6    263
# 4     Staircase          2     ch2    209
# ...         ...        ...     ...    ...
# 3220   Pathway2          3     ch2    116
# 3221        Bus          2     ch2    565
# 3222   Pathway2          2     ch6    238
# 3223  Staircase          2     ch4    117
# 3224  Staircase          4     ch6    184
#
# [3225 rows x 4 columns]

# %%
(df.groupby('scene')
   ['channel'].value_counts()
   .unstack()
   .plot.bar(stacked=True)
)
# Out:
# <AxesSubplot:xlabel='scene'>

# %%
scene_tags = df['scene'].tolist()
channel_tags = df['channel'].tolist()
scene_list = ['Pathway1','Pathway2','Doorway','Staircase','Room','Bus']
channel_list = ['ch2','ch4','ch6']
channel_filter='ch4'

# %% [markdown]
# ###  load image from pickle

# %%
import pickle
with open('/home/superorange5/Research/FedWCD/data/pickle/MI3_test_3325.pkl', 'rb') as handle:
    imgs = pickle.load(handle)

# %% [markdown]
# # 3. intermediate_layer

# %%
def vgg_intermediate(vgg, x):
    """ Get intermediate results of specifc model.
        Note: This is NOT a generalized function for all torch models,
              due to the different arch. of models.
    """
    
    # forward the features layers of VGG.
    for l in list(model.features.modules())[0]:
        x = l(x)

    # avgpool of VGG.
    x = list(model.avgpool.modules())[0](x)
    
    # flatten for FC layers.
    x = x.contiguous().view(x.shape[0], -1)
    
    # go through FC layers.
    for l in list(model.classifier.modules())[0]:
        x = l(x)

    return x

# %%
# %%time
outputs = []
batch_sz = 32
n_batch = len(imgs)//batch_sz
res_batch = len(imgs)%batch_sz

# if TARGET_LAYER == 'avgpool':
#     model.avgpool.register_forward_hook(get_activation('avgpool'))
    
# if TARGET_LAYER == 'fc':
#     model.fc.register_forward_hook(get_activation(TARGET_LAYER))
    

with torch.no_grad():

    for i in range(n_batch):
        in_batch = torch.cat(imgs[i*batch_sz:(i+1)*batch_sz]).to('cuda')

        x = vgg_intermediate(model, in_batch)
        outputs.append(x)

    # last incomplete batch.
    in_batch = torch.cat(imgs[-res_batch:]).to('cuda')
    x = vgg_intermediate(model, in_batch)
    outputs.append(x)

outputs = torch.cat(outputs)
X = outputs.to('cpu')
    
print("Output shape: {:}".format(outputs.shape))
# Out:
# Output shape: torch.Size([3225, 1000])
# CPU times: user 43.5 s, sys: 20.6 s, total: 1min 4s
# Wall time: 54.3 s

# %% [markdown]
# # 4. draw

# %% [markdown]
# ## 4A. tsne

# %% [markdown]
# ### 2D

# %%
# %%time
from sklearn.manifold import TSNE
# from sklearn.decomposition import PCA

X_embedded = TSNE(n_components=2).fit_transform(X)

# X_embedded = TSNE(n_components=2, perplexity=30.0,
#                 early_exaggeration=30.0,
#                 learning_rate=200.0,
#                 n_iter=1000,
#                 n_iter_without_progress=500,).fit_transform(X)
# Out:
# /home/superorange5/.conda/envs/py3/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /home/superorange5/.conda/envs/py3/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# CPU times: user 35.1 s, sys: 583 ms, total: 35.7 s
# Wall time: 9.9 s

# %%
len(X_embedded)
# Out:
# 3225

# %%
scene_tags = [w.replace('Pathway2', 'Pathway') for w in scene_tags]
scene_tags = [w.replace('Pathway1', 'Pathway') for w in scene_tags]

# %%
scene_tags
# Out:
# ['Pathway',
#  'Room',
#  'Pathway',
#  'Bus',
#  'Staircase',
#  'Pathway',
#  'Staircase',
#  'Pathway',
#  'Pathway',
#  'Staircase',
#  'Bus',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Staircase',
#  'Pathway',
#  'Staircase',
#  'Room',
#  'Staircase',
#  'Room',
#  'Bus',
#  'Staircase',
#  'Pathway',
#  'Bus',
#  'Bus',
#  'Pathway',
#  'Pathway',
#  'Staircase',
#  'Pathway',
#  'Pathway',
#  'Bus',
#  'Pathway',
#  'Doorway',
#  'Staircase',
#  'Bus',
#  'Staircase',
#  'Bus',
#  'Pathway',
#  'Room',
#  'Room',
#  'Pathway',
#  'Bus',
#  'Room',
#  'Pathway',
#  'Staircase',
#  'Doorway',
#  'Pathway',
#  'Bus',
#  'Pathway',
#  'Bus',
#  'Doorway',
#  'Pathway',
#  'Pathway',
#  'Bus',
#  'Pathway',
#  'Staircase',
#  'Doorway',
#  'Pathway',
#  'Staircase',
#  'Pathway',
#  'Pathway',
#  'Doorway',
#  'Pathway',
#  'Pathway',
#  'Staircase',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Bus',
#  'Room',
#  'Staircase',
#  'Staircase',
#  'Pathway',
#  'Staircase',
#  'Doorway',
#  'Staircase',
#  'Bus',
#  'Bus',
#  'Staircase',
#  'Pathway',
#  'Doorway',
#  'Staircase',
#  'Bus',
#  'Room',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Bus',
#  'Room',
#  'Pathway',
#  'Pathway',
#  'Room',
#  'Doorway',
#  'Pathway',
#  'Pathway',
#  'Staircase',
#  'Room',
#  'Pathway',
#  'Pathway',
#  'Staircase',
#  'Pathway',
#  'Pathway',
#  'Doorway',
#  'Staircase',
#  'Staircase',
#  'Room',
#  'Pathway',
#  'Pathway',
#  'Room',
#  'Doorway',
#  'Doorway',
#  'Pathway',
#  'Pathway',
#  'Staircase',
#  'Pathway',
#  'Doorway',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Bus',
#  'Staircase',
#  'Pathway',
#  'Pathway',
#  'Bus',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Doorway',
#  'Pathway',
#  'Pathway',
#  'Doorway',
#  'Pathway',
#  'Staircase',
#  'Pathway',
#  'Staircase',
#  'Room',
#  'Pathway',
#  'Staircase',
#  'Pathway',
#  'Bus',
#  'Bus',
#  'Doorway',
#  'Bus',
#  'Pathway',
#  'Bus',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Staircase',
#  'Bus',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Bus',
#  'Pathway',
#  'Staircase',
#  'Staircase',
#  'Pathway',
#  'Bus',
#  'Doorway',
#  'Bus',
#  'Staircase',
#  'Doorway',
#  'Pathway',
#  'Bus',
#  'Room',
#  'Staircase',
#  'Room',
#  'Staircase',
#  'Pathway',
#  'Bus',
#  'Pathway',
#  'Room',
#  'Doorway',
#  'Pathway',
#  'Room',
#  'Bus',
#  'Doorway',
#  'Pathway',
#  'Pathway',
#  'Bus',
#  'Staircase',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Doorway',
#  'Pathway',
#  'Staircase',
#  'Bus',
#  'Bus',
#  'Room',
#  'Pathway',
#  'Staircase',
#  'Staircase',
#  'Pathway',
#  'Staircase',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Bus',
#  'Staircase',
#  'Pathway',
#  'Staircase',
#  'Pathway',
#  'Bus',
#  'Staircase',
#  'Staircase',
#  'Pathway',
#  'Staircase',
#  'Pathway',
#  'Staircase',
#  'Staircase',
#  'Bus',
#  'Pathway',
#  'Pathway',
#  'Bus',
#  'Pathway',
#  'Staircase',
#  'Pathway',
#  'Staircase',
#  'Doorway',
#  'Room',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Bus',
#  'Pathway',
#  'Pathway',
#  'Bus',
#  'Pathway',
#  'Staircase',
#  'Room',
#  'Pathway',
#  'Pathway',
#  'Bus',
#  'Pathway',
#  'Staircase',
#  'Bus',
#  'Staircase',
#  'Staircase',
#  'Pathway',
#  'Staircase',
#  'Staircase',
#  'Staircase',
#  'Staircase',
#  'Doorway',
#  'Pathway',
#  'Staircase',
#  'Pathway',
#  'Staircase',
#  'Staircase',
#  'Pathway',
#  'Pathway',
#  'Staircase',
#  'Bus',
#  'Staircase',
#  'Pathway',
#  'Staircase',
#  'Staircase',
#  'Pathway',
#  'Pathway',
#  'Staircase',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Room',
#  'Staircase',
#  'Pathway',
#  'Pathway',
#  'Staircase',
#  'Bus',
#  'Staircase',
#  'Pathway',
#  'Pathway',
#  'Bus',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Bus',
#  'Pathway',
#  'Room',
#  'Staircase',
#  'Pathway',
#  'Doorway',
#  'Bus',
#  'Staircase',
#  'Staircase',
#  'Doorway',
#  'Staircase',
#  'Room',
#  'Room',
#  'Pathway',
#  'Bus',
#  'Staircase',
#  'Bus',
#  'Doorway',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Bus',
#  'Doorway',
#  'Pathway',
#  'Bus',
#  'Pathway',
#  'Pathway',
#  'Staircase',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Staircase',
#  'Doorway',
#  'Staircase',
#  'Bus',
#  'Pathway',
#  'Bus',
#  'Bus',
#  'Pathway',
#  'Bus',
#  'Staircase',
#  'Pathway',
#  'Pathway',
#  'Bus',
#  'Bus',
#  'Staircase',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Staircase',
#  'Pathway',
#  'Room',
#  'Bus',
#  'Pathway',
#  'Bus',
#  'Staircase',
#  'Staircase',
#  'Doorway',
#  'Pathway',
#  'Bus',
#  'Pathway',
#  'Staircase',
#  'Pathway',
#  'Doorway',
#  'Staircase',
#  'Pathway',
#  'Pathway',
#  'Doorway',
#  'Pathway',
#  'Staircase',
#  'Pathway',
#  'Pathway',
#  'Bus',
#  'Staircase',
#  'Pathway',
#  'Room',
#  'Pathway',
#  'Staircase',
#  'Pathway',
#  'Bus',
#  'Staircase',
#  'Pathway',
#  'Pathway',
#  'Bus',
#  'Bus',
#  'Pathway',
#  'Pathway',
#  'Staircase',
#  'Pathway',
#  'Room',
#  'Pathway',
#  'Pathway',
#  'Staircase',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Staircase',
#  'Pathway',
#  'Room',
#  'Pathway',
#  'Pathway',
#  'Room',
#  'Staircase',
#  'Doorway',
#  'Doorway',
#  'Pathway',
#  'Staircase',
#  'Bus',
#  'Room',
#  'Pathway',
#  'Bus',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Room',
#  'Bus',
#  'Room',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Bus',
#  'Room',
#  'Room',
#  'Pathway',
#  'Pathway',
#  'Bus',
#  'Pathway',
#  'Staircase',
#  'Pathway',
#  'Pathway',
#  'Staircase',
#  'Bus',
#  'Staircase',
#  'Bus',
#  'Pathway',
#  'Room',
#  'Staircase',
#  'Bus',
#  'Pathway',
#  'Staircase',
#  'Pathway',
#  'Pathway',
#  'Staircase',
#  'Bus',
#  'Pathway',
#  'Staircase',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Room',
#  'Doorway',
#  'Pathway',
#  'Staircase',
#  'Staircase',
#  'Pathway',
#  'Staircase',
#  'Staircase',
#  'Pathway',
#  'Room',
#  'Bus',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Staircase',
#  'Bus',
#  'Doorway',
#  'Pathway',
#  'Bus',
#  'Pathway',
#  'Doorway',
#  'Doorway',
#  'Staircase',
#  'Doorway',
#  'Doorway',
#  'Staircase',
#  'Doorway',
#  'Staircase',
#  'Bus',
#  'Pathway',
#  'Staircase',
#  'Pathway',
#  'Staircase',
#  'Room',
#  'Staircase',
#  'Bus',
#  'Pathway',
#  'Pathway',
#  'Staircase',
#  'Staircase',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Bus',
#  'Staircase',
#  'Bus',
#  'Staircase',
#  'Staircase',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Bus',
#  'Pathway',
#  'Staircase',
#  'Staircase',
#  'Bus',
#  'Staircase',
#  'Pathway',
#  'Staircase',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Bus',
#  'Staircase',
#  'Pathway',
#  'Pathway',
#  'Bus',
#  'Bus',
#  'Staircase',
#  'Bus',
#  'Bus',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Staircase',
#  'Pathway',
#  'Staircase',
#  'Pathway',
#  'Pathway',
#  'Bus',
#  'Pathway',
#  'Pathway',
#  'Room',
#  'Room',
#  'Pathway',
#  'Staircase',
#  'Staircase',
#  'Pathway',
#  'Staircase',
#  'Staircase',
#  'Pathway',
#  'Staircase',
#  'Bus',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Doorway',
#  'Bus',
#  'Doorway',
#  'Bus',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Bus',
#  'Bus',
#  'Pathway',
#  'Bus',
#  'Staircase',
#  'Pathway',
#  'Room',
#  'Pathway',
#  'Room',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Staircase',
#  'Bus',
#  'Staircase',
#  'Bus',
#  'Doorway',
#  'Pathway',
#  'Doorway',
#  'Pathway',
#  'Bus',
#  'Staircase',
#  'Pathway',
#  'Bus',
#  'Pathway',
#  'Bus',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Doorway',
#  'Staircase',
#  'Pathway',
#  'Pathway',
#  'Room',
#  'Pathway',
#  'Staircase',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Bus',
#  'Staircase',
#  'Pathway',
#  'Bus',
#  'Pathway',
#  'Pathway',
#  'Staircase',
#  'Room',
#  'Bus',
#  'Bus',
#  'Bus',
#  'Bus',
#  'Staircase',
#  'Pathway',
#  'Room',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Staircase',
#  'Pathway',
#  'Pathway',
#  'Bus',
#  'Staircase',
#  'Staircase',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Room',
#  'Pathway',
#  'Bus',
#  'Pathway',
#  'Staircase',
#  'Doorway',
#  'Doorway',
#  'Doorway',
#  'Pathway',
#  'Doorway',
#  'Pathway',
#  'Pathway',
#  'Bus',
#  'Pathway',
#  'Pathway',
#  'Bus',
#  'Pathway',
#  'Pathway',
#  'Bus',
#  'Pathway',
#  'Pathway',
#  'Doorway',
#  'Staircase',
#  'Pathway',
#  'Staircase',
#  'Staircase',
#  'Bus',
#  'Pathway',
#  'Room',
#  'Doorway',
#  'Doorway',
#  'Pathway',
#  'Pathway',
#  'Staircase',
#  'Staircase',
#  'Bus',
#  'Bus',
#  'Pathway',
#  'Pathway',
#  'Staircase',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Staircase',
#  'Bus',
#  'Room',
#  'Pathway',
#  'Staircase',
#  'Staircase',
#  'Staircase',
#  'Doorway',
#  'Pathway',
#  'Staircase',
#  'Staircase',
#  'Staircase',
#  'Pathway',
#  'Staircase',
#  'Pathway',
#  'Room',
#  'Bus',
#  'Pathway',
#  'Staircase',
#  'Staircase',
#  'Bus',
#  'Doorway',
#  'Pathway',
#  'Pathway',
#  'Bus',
#  'Staircase',
#  'Pathway',
#  'Bus',
#  'Pathway',
#  'Pathway',
#  'Bus',
#  'Bus',
#  'Bus',
#  'Pathway',
#  'Bus',
#  'Pathway',
#  'Staircase',
#  'Bus',
#  'Pathway',
#  'Doorway',
#  'Room',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Bus',
#  'Pathway',
#  'Staircase',
#  'Staircase',
#  'Staircase',
#  'Staircase',
#  'Staircase',
#  'Staircase',
#  'Staircase',
#  'Bus',
#  'Doorway',
#  'Room',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Room',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Doorway',
#  'Pathway',
#  'Doorway',
#  'Pathway',
#  'Bus',
#  'Pathway',
#  'Bus',
#  'Bus',
#  'Doorway',
#  'Bus',
#  'Staircase',
#  'Bus',
#  'Bus',
#  'Bus',
#  'Staircase',
#  'Bus',
#  'Bus',
#  'Pathway',
#  'Doorway',
#  'Doorway',
#  'Pathway',
#  'Staircase',
#  'Bus',
#  'Room',
#  'Staircase',
#  'Room',
#  'Pathway',
#  'Pathway',
#  'Room',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Doorway',
#  'Staircase',
#  'Room',
#  'Staircase',
#  'Staircase',
#  'Bus',
#  'Pathway',
#  'Bus',
#  'Room',
#  'Staircase',
#  'Pathway',
#  'Staircase',
#  'Bus',
#  'Pathway',
#  'Pathway',
#  'Bus',
#  'Pathway',
#  'Pathway',
#  'Room',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Doorway',
#  'Staircase',
#  'Doorway',
#  'Staircase',
#  'Bus',
#  'Pathway',
#  'Doorway',
#  'Room',
#  'Staircase',
#  'Pathway',
#  'Pathway',
#  'Staircase',
#  'Room',
#  'Bus',
#  'Pathway',
#  'Doorway',
#  'Pathway',
#  'Staircase',
#  'Pathway',
#  'Pathway',
#  'Staircase',
#  'Pathway',
#  'Pathway',
#  'Staircase',
#  'Staircase',
#  'Bus',
#  'Bus',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Bus',
#  'Pathway',
#  'Bus',
#  'Doorway',
#  'Pathway',
#  'Staircase',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Bus',
#  'Room',
#  'Doorway',
#  'Room',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Bus',
#  'Pathway',
#  'Pathway',
#  'Room',
#  'Staircase',
#  'Staircase',
#  'Bus',
#  'Pathway',
#  'Staircase',
#  'Pathway',
#  'Bus',
#  'Bus',
#  'Pathway',
#  'Room',
#  'Staircase',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Room',
#  'Pathway',
#  'Staircase',
#  'Doorway',
#  'Staircase',
#  'Pathway',
#  'Staircase',
#  'Pathway',
#  'Staircase',
#  'Pathway',
#  'Staircase',
#  'Pathway',
#  'Staircase',
#  'Room',
#  'Doorway',
#  'Pathway',
#  'Doorway',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Bus',
#  'Doorway',
#  'Bus',
#  'Room',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Staircase',
#  'Staircase',
#  'Pathway',
#  'Pathway',
#  'Doorway',
#  'Pathway',
#  'Pathway',
#  'Doorway',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Staircase',
#  'Pathway',
#  'Bus',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Doorway',
#  'Pathway',
#  'Pathway',
#  'Doorway',
#  'Pathway',
#  'Staircase',
#  'Pathway',
#  'Bus',
#  'Pathway',
#  'Pathway',
#  'Staircase',
#  'Staircase',
#  'Room',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Staircase',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Doorway',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Staircase',
#  'Staircase',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Room',
#  'Staircase',
#  'Staircase',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Bus',
#  'Pathway',
#  'Bus',
#  'Doorway',
#  'Doorway',
#  'Doorway',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Bus',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Doorway',
#  'Pathway',
#  'Pathway',
#  'Doorway',
#  'Pathway',
#  'Bus',
#  'Pathway',
#  'Pathway',
#  'Room',
#  'Doorway',
#  'Doorway',
#  'Pathway',
#  'Doorway',
#  'Bus',
#  'Pathway',
#  'Pathway',
#  'Doorway',
#  'Pathway',
#  'Room',
#  'Pathway',
#  'Doorway',
#  'Pathway',
#  'Pathway',
#  'Staircase',
#  'Pathway',
#  'Bus',
#  'Room',
#  'Bus',
#  'Staircase',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Pathway',
#  'Doorway',
#  'Staircase',
#  'Pathway',
#  'Bus',
#  'Bus',
#  ...]

# %%
scene_list = ['Pathway', 'Doorway', 'Staircase', 'Room', 'Bus']

# %%
from matplotlib import pyplot as plt
fig, ax = plt.subplots()
#fig, ax =plt.figure(figsize=(12, 12));
channel_filter='ch4'
for idx, tag in enumerate(scene_list):
    
    #mask = np.asarray(scene_tags) == tag
    mask = np.logical_and( np.asarray(scene_tags) == tag , np.asarray(channel_tags)==channel_filter)
    ax.scatter(X_embedded[mask, 0], X_embedded[mask, 1], label=tag, alpha=0.7)
ax.tick_params(axis='y',labelsize=18) 
ax.tick_params(axis='x',labelsize=18)    

fig.tight_layout()


fig.set_size_inches(8, 8)
    
plt.legend(fontsize=20);

# %% [markdown]
# ### 3D

# %%
# %%time
# from sklearn.decomposition import PCA.
X_embedded_3d = TSNE(n_components=3).fit_transform(X)
# Out:
# /home/superorange5/.conda/envs/py3/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /home/superorange5/.conda/envs/py3/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# CPU times: user 1min 4s, sys: 358 ms, total: 1min 4s
# Wall time: 16.4 s

# %%
fig = plt.figure(figsize=(12, 12))
ax = plt.axes(projection='3d')

# X_embedded_3d = TSNE(n_components=3).fit_transform(X[:,:,0,0])
channel_filter = 'ch4'
angle = -90
ax.view_init(10, angle)

for idx, tag in enumerate(scene_list):
    #mask = np.asarray(scene_tags) == tag
    mask = np.logical_and( np.asarray(scene_tags) == tag , np.asarray(channel_tags)==channel_filter)

    ax.scatter3D(X_embedded_3d[mask, 0], X_embedded_3d[mask, 1], X_embedded_3d[mask, 2], label=tag, alpha=0.7)
    
plt.legend(fontsize=14);

# %% [markdown]
# ## 4B. PCA

# %%
from sklearn.decomposition import PCA
#pca = PCA(n_components=2)
pca = PCA(n_components=2).fit_transform(X)
pca_3D = PCA(n_components=3).fit_transform(X)

#x_new= X
#mask = np.logical_and( np.asarray(scene_tags) == tag , np.asarray(channel_tags)==channel_filter)
#plt.scatter(X_embedded[mask, 0], X_embedded[mask, 1], label=tag, alpha=0.7)
   
#pca.fit(x_new)

# %% [markdown]
# ### 2D

# %%
from matplotlib import pyplot as plt

plt.figure(figsize=(12, 12));

for idx, tag in enumerate(scene_list):
    
    #mask = np.asarray(scene_tags) == tag
    mask = np.logical_and( np.asarray(scene_tags) == tag , np.asarray(channel_tags)==channel_filter)
    plt.scatter(pca[mask, 0], pca[mask, 1], label=tag, alpha=0.7)
    
plt.legend(fontsize=14);

# %% [markdown]
# ### PCA 3D

# %%
fig = plt.figure(figsize=(12, 12))
ax = plt.axes(projection='3d')

for idx, tag in enumerate(scene_list):
    #mask = np.asarray(scene_tags) == tag
    mask = np.logical_and( np.asarray(scene_tags) == tag , np.asarray(channel_tags)==channel_filter)

    ax.scatter3D(pca_3D[mask, 0], pca_3D[mask, 1], pca_3D[mask, 2], label=tag, alpha=0.7)
    
plt.legend(fontsize=14);

# %% [markdown]
# # Backup

# %%
import numpy as np
import pandas as pd
from sklearn.cluster import KMeans

def optimalK(data, nrefs=5, maxClusters=15):
    """
    Calculates KMeans optimal K using Gap Statistic from Tibshirani, Walther, Hastie
    Params:
        data: ndarry of shape (n_samples, n_features)
        nrefs: number of sample reference datasets to create
        maxClusters: Maximum number of clusters to test for
    Returns: (gaps, optimalK)
    """
    gaps = np.zeros((len(range(1, maxClusters)),))
    resultsdf = pd.DataFrame({'clusterCount':[], 'gap':[]})
    for gap_index, k in enumerate(range(1, maxClusters)):
#     for gap_index, k in enumerate(range(10, 50, 5)):

        # Holder for reference dispersion results
        refDisps = np.zeros(nrefs)

        # For n references, generate random sample and perform kmeans getting resulting dispersion of each loop
        for i in range(nrefs):
            
            # Create new random reference set
            randomReference = np.random.random_sample(size=data.shape)
            
            # Fit to it
            km = KMeans(k)
            km.fit(randomReference)
            
            refDisp = km.inertia_
            refDisps[i] = refDisp

        # Fit cluster to original data and create dispersion
        km = KMeans(k)
        km.fit(data)
        
        origDisp = km.inertia_

        # Calculate gap statistic
        gap = np.log(np.mean(refDisps)) - np.log(origDisp)

        # Assign this loop's gap statistic to gaps
        gaps[gap_index] = gap
        
        resultsdf = resultsdf.append({'clusterCount':k, 'gap':gap}, ignore_index=True)

    return (gaps.argmax() + 1, resultsdf)  # Plus 1 because index of 0 means 1 cluster is optimal, index 2 = 3 clusters are optimal

# %%
# %%time
k, gapdf = optimalK(X_embedded, nrefs=5, maxClusters=20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <timed exec> in <module>
#
# NameError: name 'X_embedded' is not defined

# %%
plt.plot(gapdf.clusterCount, gapdf.gap, linewidth=3)
plt.scatter(gapdf[gapdf.clusterCount == k].clusterCount, gapdf[gapdf.clusterCount == k].gap, s=250, c='r')
plt.grid(True)
plt.xlabel('Cluster Count')
plt.ylabel('Gap Value')
plt.title('Gap Values by Cluster Count')
plt.show()

# %%
# from sklearn.decomposition import PCA

# pca_3d = PCA(n_components=3).fit_transform(X[])

# %%
# fig = plt.figure(figsize=(12, 12))
# ax = plt.axes(projection='3d')

# for idx, tag in enumerate(['campus', 'road', 'downtown']):
#     mask = np.asarray(scene_tags) == tag
    
#     ax.scatter3D(pca_3d[mask, 0], pca_3d[mask, 1], pca_3d[mask, 2], label=tag, alpha=0.7)
    
# plt.legend(fontsize=14);
